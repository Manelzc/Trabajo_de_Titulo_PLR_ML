# %%
from __future__ import print_function

from tensorflow import keras
import numpy as np
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# ImportError: DLL load failed while importing _multiarray_umath: No se puede encontrar el módulo especificado.

# %%
import tensorflow as tf; print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# Num GPUs Available:  1

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split

# Función para leer y procesar el archivo CSV
def load_and_preprocess_data(filename):
    # Leer el archivo CSV
    df = pd.read_csv(filename)

    df = df[df['stimuli'] == 'flash']

    # Realizar el split basado en el id del paciente
    unique_ids = df['id'].unique()
    train_ids, test_ids = train_test_split(unique_ids, test_size=0.2, random_state=26)

    train_set = df[df['id'].isin(train_ids)]
    test_set = df[df['id'].isin(test_ids)]

    # Descartar las columnas no necesarias
    train_set = train_set.drop(columns=['id', 'eye', 'stimuli', 'color'])
    test_set = test_set.drop(columns=['id', 'eye', 'stimuli', 'color'])

    # Convertir la columna 'glaucoma' en etiquetas binarias
    train_set['glaucoma'] = train_set['glaucoma'].apply(lambda x: 1 if x == 'yes' else 0)
    test_set['glaucoma'] = test_set['glaucoma'].apply(lambda x: 1 if x == 'yes' else 0)

    # Separar las etiquetas de las características
    y_train = train_set['glaucoma'].values
    X_train = train_set.drop(columns=['glaucoma']).values

    y_test = test_set['glaucoma'].values
    X_test = test_set.drop(columns=['glaucoma']).values

    return X_train, y_train, X_test, y_test

# Uso de la función
filename = 'dataset_sat_fill.csv'
x_train, y_train, x_test, y_test = load_and_preprocess_data(filename)

# Dividir el conjunto de entrenamiento en un conjunto de entrenamiento y uno de validación
x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size=0.2, random_state=26)

# %%
# Cambiar el formato de x_train y x_test a (n_samples, timesteps, features)
# Aquí, 'timesteps' es el número de muestras en la secuencia (por ejemplo, 2770 en mi caso),
# y 'features' es 1, ya que cada paso de tiempo tiene solo una característica.

x_train = x_train.reshape((x_train.shape[0], x_train.shape[1], 1))
x_test = x_test.reshape((x_test.shape[0], x_test.shape[1], 1))
x_val = x_val.reshape((x_val.shape[0], x_val.shape[1], 1))

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import GRU, Dense
from tensorflow.keras.optimizers import Adam

# Definir el modelo
model = Sequential()
model.add(GRU(64, input_shape=(x_train.shape[1], x_train.shape[2]), return_sequences=True))
model.add(GRU(32))
model.add(Dense(1, activation='sigmoid'))  # Activación sigmoide para clasificación binaria

# Compilar el modelo
model.compile(optimizer=Adam(), loss='binary_crossentropy', metrics=['accuracy'])

# %%
from tensorflow.keras.callbacks import ModelCheckpoint

# Configurar el callback para guardar el mejor modelo
checkpoint = ModelCheckpoint('GRU_model_6.h5', monitor='val_loss', 
                             save_best_only=True, mode='min', verbose=1)

# Configurar la reducción de la tasa de aprendizaje
reduce_lr = keras.callbacks.ReduceLROnPlateau(monitor='loss', factor=0.5,
                                              patience=50, min_lr=0.0001)


# Entrenar el modelo
history = model.fit(x_train, y_train, epochs=100, batch_size=16, validation_data=(x_val, y_val), callbacks = [checkpoint, reduce_lr])
# Out:
# Epoch 1/100
# 13/13 [==============================] - ETA: 0s - loss: 0.7497 - accuracy: 0.4461
# Epoch 1: val_loss improved from inf to 0.70159, saving model to GRU_model_6.h5
# 13/13 [==============================] - 8s 295ms/step - loss: 0.7497 - accuracy: 0.4461 - val_loss: 0.7016 - val_accuracy: 0.4423 - lr: 0.0010
# Epoch 2/100
# 13/13 [==============================] - ETA: 0s - loss: 0.7055 - accuracy: 0.5049
# Epoch 2: val_loss improved from 0.70159 to 0.69303, saving model to GRU_model_6.h5
# 13/13 [==============================] - 3s 235ms/step - loss: 0.7055 - accuracy: 0.5049 - val_loss: 0.6930 - val_accuracy: 0.4615 - lr: 0.0010
# Epoch 3/100
# 13/13 [==============================] - ETA: 0s - loss: 0.6791 - accuracy: 0.5980
# Epoch 3: val_loss improved from 0.69303 to 0.68424, saving model to GRU_model_6.h5
# 13/13 [==============================] - 3s 236ms/step - loss: 0.6791 - accuracy: 0.5980 - val_loss: 0.6842 - val_accuracy: 0.5769 - lr: 0.0010
# Epoch 4/100
# 13/13 [==============================] - ETA: 0s - loss: 0.6626 - accuracy: 0.6029
# Epoch 4: val_loss improved from 0.68424 to 0.67749, saving model to GRU_model_6.h5
# 13/13 [==============================] - 3s 234ms/step - loss: 0.6626 - accuracy: 0.6029 - val_loss: 0.6775 - val_accuracy: 0.5769 - lr: 0.0010
# Epoch 5/100
# 13/13 [==============================] - ETA: 0s - loss: 0.6469 - accuracy: 0.6471
# Epoch 5: val_loss improved from 0.67749 to 0.67546, saving model to GRU_model_6.h5
# 13/13 [==============================] - 3s 234ms/step - loss: 0.6469 - accuracy: 0.6471 - val_loss: 0.6755 - val_accuracy: 0.5769 - lr: 0.0010
# Epoch 6/100
# 13/13 [==============================] - ETA: 0s - loss: 0.6451 - accuracy: 0.5980
# Epoch 6: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 230ms/step - loss: 0.6451 - accuracy: 0.5980 - val_loss: 0.6797 - val_accuracy: 0.5577 - lr: 0.0010
# Epoch 7/100
# 13/13 [==============================] - ETA: 0s - loss: 0.6471 - accuracy: 0.6127
# Epoch 7: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 233ms/step - loss: 0.6471 - accuracy: 0.6127 - val_loss: 0.7090 - val_accuracy: 0.5192 - lr: 0.0010
# Epoch 8/100
# 13/13 [==============================] - ETA: 0s - loss: 0.6196 - accuracy: 0.6667
# Epoch 8: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 230ms/step - loss: 0.6196 - accuracy: 0.6667 - val_loss: 0.7042 - val_accuracy: 0.5769 - lr: 0.0010
# Epoch 9/100
# 13/13 [==============================] - ETA: 0s - loss: 0.6188 - accuracy: 0.6471
# Epoch 9: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 232ms/step - loss: 0.6188 - accuracy: 0.6471 - val_loss: 0.6883 - val_accuracy: 0.5577 - lr: 0.0010
# Epoch 10/100
# 13/13 [==============================] - ETA: 0s - loss: 0.5947 - accuracy: 0.6520
# Epoch 10: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 231ms/step - loss: 0.5947 - accuracy: 0.6520 - val_loss: 0.6885 - val_accuracy: 0.5769 - lr: 0.0010
# Epoch 11/100
# 13/13 [==============================] - ETA: 0s - loss: 0.5924 - accuracy: 0.6471
# Epoch 11: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 232ms/step - loss: 0.5924 - accuracy: 0.6471 - val_loss: 0.7008 - val_accuracy: 0.5385 - lr: 0.0010
# Epoch 12/100
# 13/13 [==============================] - ETA: 0s - loss: 0.5835 - accuracy: 0.6912
# Epoch 12: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 230ms/step - loss: 0.5835 - accuracy: 0.6912 - val_loss: 0.7020 - val_accuracy: 0.5577 - lr: 0.0010
# Epoch 13/100
# 13/13 [==============================] - ETA: 0s - loss: 0.5807 - accuracy: 0.6863
# Epoch 13: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 231ms/step - loss: 0.5807 - accuracy: 0.6863 - val_loss: 0.7267 - val_accuracy: 0.5769 - lr: 0.0010
# Epoch 14/100
# 13/13 [==============================] - ETA: 0s - loss: 0.5842 - accuracy: 0.6667
# Epoch 14: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 232ms/step - loss: 0.5842 - accuracy: 0.6667 - val_loss: 0.7112 - val_accuracy: 0.5192 - lr: 0.0010
# Epoch 15/100
# 13/13 [==============================] - ETA: 0s - loss: 0.5734 - accuracy: 0.6716
# Epoch 15: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 229ms/step - loss: 0.5734 - accuracy: 0.6716 - val_loss: 0.7946 - val_accuracy: 0.5000 - lr: 0.0010
# Epoch 16/100
# 13/13 [==============================] - ETA: 0s - loss: 0.5838 - accuracy: 0.6569
# Epoch 16: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 230ms/step - loss: 0.5838 - accuracy: 0.6569 - val_loss: 0.7066 - val_accuracy: 0.5192 - lr: 0.0010
# Epoch 17/100
# 13/13 [==============================] - ETA: 0s - loss: 0.5553 - accuracy: 0.6912
# Epoch 17: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 230ms/step - loss: 0.5553 - accuracy: 0.6912 - val_loss: 0.7189 - val_accuracy: 0.5962 - lr: 0.0010
# Epoch 18/100
# 13/13 [==============================] - ETA: 0s - loss: 0.5479 - accuracy: 0.7157
# Epoch 18: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 231ms/step - loss: 0.5479 - accuracy: 0.7157 - val_loss: 0.7517 - val_accuracy: 0.5577 - lr: 0.0010
# Epoch 19/100
# 13/13 [==============================] - ETA: 0s - loss: 0.5459 - accuracy: 0.6765
# Epoch 19: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 235ms/step - loss: 0.5459 - accuracy: 0.6765 - val_loss: 0.7215 - val_accuracy: 0.6154 - lr: 0.0010
# Epoch 20/100
# 13/13 [==============================] - ETA: 0s - loss: 0.5358 - accuracy: 0.7108
# Epoch 20: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 229ms/step - loss: 0.5358 - accuracy: 0.7108 - val_loss: 0.7716 - val_accuracy: 0.5962 - lr: 0.0010
# Epoch 21/100
# 13/13 [==============================] - ETA: 0s - loss: 0.5193 - accuracy: 0.7353
# Epoch 21: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 230ms/step - loss: 0.5193 - accuracy: 0.7353 - val_loss: 0.7717 - val_accuracy: 0.5962 - lr: 0.0010
# Epoch 22/100
# 13/13 [==============================] - ETA: 0s - loss: 0.5212 - accuracy: 0.7157
# Epoch 22: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 229ms/step - loss: 0.5212 - accuracy: 0.7157 - val_loss: 0.7842 - val_accuracy: 0.5385 - lr: 0.0010
# Epoch 23/100
# 13/13 [==============================] - ETA: 0s - loss: 0.5362 - accuracy: 0.7304
# Epoch 23: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 230ms/step - loss: 0.5362 - accuracy: 0.7304 - val_loss: 0.8287 - val_accuracy: 0.5962 - lr: 0.0010
# Epoch 24/100
# 13/13 [==============================] - ETA: 0s - loss: 0.5025 - accuracy: 0.7647
# Epoch 24: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 230ms/step - loss: 0.5025 - accuracy: 0.7647 - val_loss: 0.8133 - val_accuracy: 0.5769 - lr: 0.0010
# Epoch 25/100
# 13/13 [==============================] - ETA: 0s - loss: 0.5040 - accuracy: 0.7990
# Epoch 25: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 231ms/step - loss: 0.5040 - accuracy: 0.7990 - val_loss: 0.9516 - val_accuracy: 0.5192 - lr: 0.0010
# Epoch 26/100
# 13/13 [==============================] - ETA: 0s - loss: 0.5091 - accuracy: 0.7206
# Epoch 26: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 230ms/step - loss: 0.5091 - accuracy: 0.7206 - val_loss: 0.8435 - val_accuracy: 0.5769 - lr: 0.0010
# Epoch 27/100
# 13/13 [==============================] - ETA: 0s - loss: 0.5017 - accuracy: 0.7255
# Epoch 27: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 231ms/step - loss: 0.5017 - accuracy: 0.7255 - val_loss: 0.8349 - val_accuracy: 0.5000 - lr: 0.0010
# Epoch 28/100
# 13/13 [==============================] - ETA: 0s - loss: 0.4971 - accuracy: 0.7451
# Epoch 28: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 230ms/step - loss: 0.4971 - accuracy: 0.7451 - val_loss: 0.7922 - val_accuracy: 0.5577 - lr: 0.0010
# Epoch 29/100
# 13/13 [==============================] - ETA: 0s - loss: 0.4859 - accuracy: 0.7843
# Epoch 29: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 231ms/step - loss: 0.4859 - accuracy: 0.7843 - val_loss: 0.9055 - val_accuracy: 0.5962 - lr: 0.0010
# Epoch 30/100
# 13/13 [==============================] - ETA: 0s - loss: 0.4709 - accuracy: 0.7941
# Epoch 30: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 231ms/step - loss: 0.4709 - accuracy: 0.7941 - val_loss: 0.8951 - val_accuracy: 0.5962 - lr: 0.0010
# Epoch 31/100
# 13/13 [==============================] - ETA: 0s - loss: 0.4571 - accuracy: 0.7794
# Epoch 31: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 230ms/step - loss: 0.4571 - accuracy: 0.7794 - val_loss: 0.8905 - val_accuracy: 0.6154 - lr: 0.0010
# Epoch 32/100
# 13/13 [==============================] - ETA: 0s - loss: 0.4511 - accuracy: 0.7892
# Epoch 32: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 231ms/step - loss: 0.4511 - accuracy: 0.7892 - val_loss: 0.8932 - val_accuracy: 0.5577 - lr: 0.0010
# Epoch 33/100
# 13/13 [==============================] - ETA: 0s - loss: 0.4366 - accuracy: 0.8333
# Epoch 33: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 230ms/step - loss: 0.4366 - accuracy: 0.8333 - val_loss: 1.0111 - val_accuracy: 0.5577 - lr: 0.0010
# Epoch 34/100
# 13/13 [==============================] - ETA: 0s - loss: 0.4557 - accuracy: 0.7794
# Epoch 34: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 229ms/step - loss: 0.4557 - accuracy: 0.7794 - val_loss: 0.9770 - val_accuracy: 0.5577 - lr: 0.0010
# Epoch 35/100
# 13/13 [==============================] - ETA: 0s - loss: 0.4446 - accuracy: 0.7794
# Epoch 35: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 230ms/step - loss: 0.4446 - accuracy: 0.7794 - val_loss: 0.9868 - val_accuracy: 0.6346 - lr: 0.0010
# Epoch 36/100
# 13/13 [==============================] - ETA: 0s - loss: 0.4390 - accuracy: 0.7794
# Epoch 36: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 231ms/step - loss: 0.4390 - accuracy: 0.7794 - val_loss: 0.9173 - val_accuracy: 0.5769 - lr: 0.0010
# Epoch 37/100
# 13/13 [==============================] - ETA: 0s - loss: 0.4307 - accuracy: 0.7892
# Epoch 37: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 232ms/step - loss: 0.4307 - accuracy: 0.7892 - val_loss: 0.9861 - val_accuracy: 0.6154 - lr: 0.0010
# Epoch 38/100
# 13/13 [==============================] - ETA: 0s - loss: 0.4520 - accuracy: 0.7941
# Epoch 38: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 231ms/step - loss: 0.4520 - accuracy: 0.7941 - val_loss: 1.0344 - val_accuracy: 0.5577 - lr: 0.0010
# Epoch 39/100
# 13/13 [==============================] - ETA: 0s - loss: 0.4342 - accuracy: 0.7941
# Epoch 39: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 234ms/step - loss: 0.4342 - accuracy: 0.7941 - val_loss: 0.9447 - val_accuracy: 0.5769 - lr: 0.0010
# Epoch 40/100
# 13/13 [==============================] - ETA: 0s - loss: 0.4231 - accuracy: 0.7892
# Epoch 40: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 231ms/step - loss: 0.4231 - accuracy: 0.7892 - val_loss: 1.0339 - val_accuracy: 0.5385 - lr: 0.0010
# Epoch 41/100
# 13/13 [==============================] - ETA: 0s - loss: 0.4362 - accuracy: 0.7794
# Epoch 41: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 230ms/step - loss: 0.4362 - accuracy: 0.7794 - val_loss: 0.9919 - val_accuracy: 0.5769 - lr: 0.0010
# Epoch 42/100
# 13/13 [==============================] - ETA: 0s - loss: 0.4307 - accuracy: 0.7843
# Epoch 42: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 230ms/step - loss: 0.4307 - accuracy: 0.7843 - val_loss: 0.9497 - val_accuracy: 0.5192 - lr: 0.0010
# Epoch 43/100
# 13/13 [==============================] - ETA: 0s - loss: 0.4232 - accuracy: 0.7745
# Epoch 43: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 230ms/step - loss: 0.4232 - accuracy: 0.7745 - val_loss: 1.0538 - val_accuracy: 0.6346 - lr: 0.0010
# Epoch 44/100
# 13/13 [==============================] - ETA: 0s - loss: 0.4003 - accuracy: 0.8186
# Epoch 44: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 234ms/step - loss: 0.4003 - accuracy: 0.8186 - val_loss: 0.9912 - val_accuracy: 0.5962 - lr: 0.0010
# Epoch 45/100
# 13/13 [==============================] - ETA: 0s - loss: 0.4134 - accuracy: 0.7892
# Epoch 45: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 230ms/step - loss: 0.4134 - accuracy: 0.7892 - val_loss: 0.9879 - val_accuracy: 0.6538 - lr: 0.0010
# Epoch 46/100
# 13/13 [==============================] - ETA: 0s - loss: 0.3943 - accuracy: 0.8137
# Epoch 46: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 231ms/step - loss: 0.3943 - accuracy: 0.8137 - val_loss: 0.9914 - val_accuracy: 0.6154 - lr: 0.0010
# Epoch 47/100
# 13/13 [==============================] - ETA: 0s - loss: 0.3957 - accuracy: 0.8186
# Epoch 47: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 233ms/step - loss: 0.3957 - accuracy: 0.8186 - val_loss: 1.0444 - val_accuracy: 0.6346 - lr: 0.0010
# Epoch 48/100
# 13/13 [==============================] - ETA: 0s - loss: 0.3930 - accuracy: 0.8186
# Epoch 48: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 231ms/step - loss: 0.3930 - accuracy: 0.8186 - val_loss: 1.0568 - val_accuracy: 0.6154 - lr: 0.0010
# Epoch 49/100
# 13/13 [==============================] - ETA: 0s - loss: 0.4600 - accuracy: 0.7549
# Epoch 49: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 231ms/step - loss: 0.4600 - accuracy: 0.7549 - val_loss: 0.9891 - val_accuracy: 0.5577 - lr: 0.0010
# Epoch 50/100
# 13/13 [==============================] - ETA: 0s - loss: 0.4234 - accuracy: 0.7990
# Epoch 50: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 231ms/step - loss: 0.4234 - accuracy: 0.7990 - val_loss: 0.9481 - val_accuracy: 0.6538 - lr: 0.0010
# Epoch 51/100
# 13/13 [==============================] - ETA: 0s - loss: 0.3884 - accuracy: 0.8284
# Epoch 51: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 230ms/step - loss: 0.3884 - accuracy: 0.8284 - val_loss: 1.0885 - val_accuracy: 0.5962 - lr: 0.0010
# Epoch 52/100
# 13/13 [==============================] - ETA: 0s - loss: 0.3878 - accuracy: 0.8088
# Epoch 52: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 231ms/step - loss: 0.3878 - accuracy: 0.8088 - val_loss: 1.0127 - val_accuracy: 0.5577 - lr: 0.0010
# Epoch 53/100
# 13/13 [==============================] - ETA: 0s - loss: 0.4355 - accuracy: 0.7794
# Epoch 53: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 230ms/step - loss: 0.4355 - accuracy: 0.7794 - val_loss: 1.0092 - val_accuracy: 0.6346 - lr: 0.0010
# Epoch 54/100
# 13/13 [==============================] - ETA: 0s - loss: 0.4009 - accuracy: 0.7941
# Epoch 54: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 231ms/step - loss: 0.4009 - accuracy: 0.7941 - val_loss: 1.1471 - val_accuracy: 0.5577 - lr: 0.0010
# Epoch 55/100
# 13/13 [==============================] - ETA: 0s - loss: 0.4062 - accuracy: 0.8186
# Epoch 55: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 235ms/step - loss: 0.4062 - accuracy: 0.8186 - val_loss: 1.0881 - val_accuracy: 0.6154 - lr: 0.0010
# Epoch 56/100
# 13/13 [==============================] - ETA: 0s - loss: 0.3934 - accuracy: 0.8235
# Epoch 56: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 229ms/step - loss: 0.3934 - accuracy: 0.8235 - val_loss: 1.0388 - val_accuracy: 0.6154 - lr: 0.0010
# Epoch 57/100
# 13/13 [==============================] - ETA: 0s - loss: 0.3989 - accuracy: 0.7843
# Epoch 57: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 232ms/step - loss: 0.3989 - accuracy: 0.7843 - val_loss: 1.0109 - val_accuracy: 0.5577 - lr: 0.0010
# Epoch 58/100
# 13/13 [==============================] - ETA: 0s - loss: 0.4139 - accuracy: 0.7990
# Epoch 58: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 232ms/step - loss: 0.4139 - accuracy: 0.7990 - val_loss: 1.0460 - val_accuracy: 0.6154 - lr: 0.0010
# Epoch 59/100
# 13/13 [==============================] - ETA: 0s - loss: 0.3704 - accuracy: 0.8284
# Epoch 59: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 232ms/step - loss: 0.3704 - accuracy: 0.8284 - val_loss: 1.0180 - val_accuracy: 0.5962 - lr: 0.0010
# Epoch 60/100
# 13/13 [==============================] - ETA: 0s - loss: 0.3522 - accuracy: 0.8431
# Epoch 60: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 231ms/step - loss: 0.3522 - accuracy: 0.8431 - val_loss: 1.0592 - val_accuracy: 0.6346 - lr: 0.0010
# Epoch 61/100
# 13/13 [==============================] - ETA: 0s - loss: 0.3764 - accuracy: 0.8235
# Epoch 61: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 232ms/step - loss: 0.3764 - accuracy: 0.8235 - val_loss: 1.0077 - val_accuracy: 0.6538 - lr: 0.0010
# Epoch 62/100
# 13/13 [==============================] - ETA: 0s - loss: 0.3403 - accuracy: 0.8529
# Epoch 62: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 230ms/step - loss: 0.3403 - accuracy: 0.8529 - val_loss: 1.1567 - val_accuracy: 0.6346 - lr: 0.0010
# Epoch 63/100
# 13/13 [==============================] - ETA: 0s - loss: 0.3473 - accuracy: 0.8480
# Epoch 63: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 230ms/step - loss: 0.3473 - accuracy: 0.8480 - val_loss: 1.1395 - val_accuracy: 0.5962 - lr: 0.0010
# Epoch 64/100
# 13/13 [==============================] - ETA: 0s - loss: 0.3296 - accuracy: 0.8676
# Epoch 64: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 230ms/step - loss: 0.3296 - accuracy: 0.8676 - val_loss: 1.0886 - val_accuracy: 0.6346 - lr: 0.0010
# Epoch 65/100
# 13/13 [==============================] - ETA: 0s - loss: 0.2981 - accuracy: 0.8725
# Epoch 65: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 230ms/step - loss: 0.2981 - accuracy: 0.8725 - val_loss: 1.2585 - val_accuracy: 0.5962 - lr: 0.0010
# Epoch 66/100
# 13/13 [==============================] - ETA: 0s - loss: 0.3220 - accuracy: 0.8480
# Epoch 66: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 231ms/step - loss: 0.3220 - accuracy: 0.8480 - val_loss: 1.1812 - val_accuracy: 0.5962 - lr: 0.0010
# Epoch 67/100
# 13/13 [==============================] - ETA: 0s - loss: 0.3121 - accuracy: 0.8529
# Epoch 67: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 231ms/step - loss: 0.3121 - accuracy: 0.8529 - val_loss: 1.2955 - val_accuracy: 0.6154 - lr: 0.0010
# Epoch 68/100
# 13/13 [==============================] - ETA: 0s - loss: 0.3109 - accuracy: 0.8578
# Epoch 68: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 229ms/step - loss: 0.3109 - accuracy: 0.8578 - val_loss: 1.3259 - val_accuracy: 0.6154 - lr: 0.0010
# Epoch 69/100
# 13/13 [==============================] - ETA: 0s - loss: 0.3174 - accuracy: 0.8529
# Epoch 69: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 230ms/step - loss: 0.3174 - accuracy: 0.8529 - val_loss: 1.2683 - val_accuracy: 0.6538 - lr: 0.0010
# Epoch 70/100
# 13/13 [==============================] - ETA: 0s - loss: 0.2932 - accuracy: 0.8824
# Epoch 70: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 230ms/step - loss: 0.2932 - accuracy: 0.8824 - val_loss: 1.3008 - val_accuracy: 0.5769 - lr: 0.0010
# Epoch 71/100
# 13/13 [==============================] - ETA: 0s - loss: 0.2985 - accuracy: 0.8529
# Epoch 71: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 230ms/step - loss: 0.2985 - accuracy: 0.8529 - val_loss: 1.2103 - val_accuracy: 0.6538 - lr: 0.0010
# Epoch 72/100
# 13/13 [==============================] - ETA: 0s - loss: 0.2819 - accuracy: 0.8627
# Epoch 72: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 231ms/step - loss: 0.2819 - accuracy: 0.8627 - val_loss: 1.2497 - val_accuracy: 0.6538 - lr: 0.0010
# Epoch 73/100
# 13/13 [==============================] - ETA: 0s - loss: 0.2867 - accuracy: 0.9020
# Epoch 73: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 231ms/step - loss: 0.2867 - accuracy: 0.9020 - val_loss: 1.3087 - val_accuracy: 0.5769 - lr: 0.0010
# Epoch 74/100
# 13/13 [==============================] - ETA: 0s - loss: 0.3707 - accuracy: 0.8137
# Epoch 74: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 232ms/step - loss: 0.3707 - accuracy: 0.8137 - val_loss: 1.4027 - val_accuracy: 0.5192 - lr: 0.0010
# Epoch 75/100
# 13/13 [==============================] - ETA: 0s - loss: 0.4252 - accuracy: 0.7990
# Epoch 75: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 233ms/step - loss: 0.4252 - accuracy: 0.7990 - val_loss: 1.2506 - val_accuracy: 0.6154 - lr: 0.0010
# Epoch 76/100
# 13/13 [==============================] - ETA: 0s - loss: 0.3036 - accuracy: 0.8578
# Epoch 76: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 230ms/step - loss: 0.3036 - accuracy: 0.8578 - val_loss: 1.0485 - val_accuracy: 0.6154 - lr: 0.0010
# Epoch 77/100
# 13/13 [==============================] - ETA: 0s - loss: 0.2724 - accuracy: 0.8873
# Epoch 77: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 231ms/step - loss: 0.2724 - accuracy: 0.8873 - val_loss: 1.1831 - val_accuracy: 0.6538 - lr: 0.0010
# Epoch 78/100
# 13/13 [==============================] - ETA: 0s - loss: 0.2441 - accuracy: 0.8971
# Epoch 78: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 232ms/step - loss: 0.2441 - accuracy: 0.8971 - val_loss: 1.3059 - val_accuracy: 0.6154 - lr: 0.0010
# Epoch 79/100
# 13/13 [==============================] - ETA: 0s - loss: 0.2483 - accuracy: 0.9020
# Epoch 79: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 233ms/step - loss: 0.2483 - accuracy: 0.9020 - val_loss: 1.3374 - val_accuracy: 0.6538 - lr: 0.0010
# Epoch 80/100
# 13/13 [==============================] - ETA: 0s - loss: 0.2580 - accuracy: 0.8922
# Epoch 80: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 231ms/step - loss: 0.2580 - accuracy: 0.8922 - val_loss: 1.3485 - val_accuracy: 0.6346 - lr: 0.0010
# Epoch 81/100
# 13/13 [==============================] - ETA: 0s - loss: 0.2254 - accuracy: 0.9020
# Epoch 81: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 231ms/step - loss: 0.2254 - accuracy: 0.9020 - val_loss: 1.2796 - val_accuracy: 0.5962 - lr: 0.0010
# Epoch 82/100
# 13/13 [==============================] - ETA: 0s - loss: 0.1821 - accuracy: 0.9314
# Epoch 82: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 238ms/step - loss: 0.1821 - accuracy: 0.9314 - val_loss: 1.4055 - val_accuracy: 0.6538 - lr: 0.0010
# Epoch 83/100
# 13/13 [==============================] - ETA: 0s - loss: 0.2012 - accuracy: 0.9265
# Epoch 83: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 240ms/step - loss: 0.2012 - accuracy: 0.9265 - val_loss: 1.5757 - val_accuracy: 0.5962 - lr: 0.0010
# Epoch 84/100
# 13/13 [==============================] - ETA: 0s - loss: 0.2003 - accuracy: 0.9069
# Epoch 84: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 231ms/step - loss: 0.2003 - accuracy: 0.9069 - val_loss: 1.5185 - val_accuracy: 0.5962 - lr: 0.0010
# Epoch 85/100
# 13/13 [==============================] - ETA: 0s - loss: 0.2043 - accuracy: 0.9167
# Epoch 85: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 232ms/step - loss: 0.2043 - accuracy: 0.9167 - val_loss: 1.5346 - val_accuracy: 0.6538 - lr: 0.0010
# Epoch 86/100
# 13/13 [==============================] - ETA: 0s - loss: 0.2205 - accuracy: 0.9069
# Epoch 86: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 230ms/step - loss: 0.2205 - accuracy: 0.9069 - val_loss: 1.3391 - val_accuracy: 0.5769 - lr: 0.0010
# Epoch 87/100
# 13/13 [==============================] - ETA: 0s - loss: 0.2190 - accuracy: 0.9020
# Epoch 87: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 234ms/step - loss: 0.2190 - accuracy: 0.9020 - val_loss: 1.4297 - val_accuracy: 0.5769 - lr: 0.0010
# Epoch 88/100
# 13/13 [==============================] - ETA: 0s - loss: 0.1889 - accuracy: 0.9265
# Epoch 88: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 231ms/step - loss: 0.1889 - accuracy: 0.9265 - val_loss: 1.4625 - val_accuracy: 0.5962 - lr: 0.0010
# Epoch 89/100
# 13/13 [==============================] - ETA: 0s - loss: 0.1723 - accuracy: 0.9363
# Epoch 89: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 230ms/step - loss: 0.1723 - accuracy: 0.9363 - val_loss: 1.5076 - val_accuracy: 0.6154 - lr: 0.0010
# Epoch 90/100
# 13/13 [==============================] - ETA: 0s - loss: 0.1774 - accuracy: 0.9314
# Epoch 90: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 229ms/step - loss: 0.1774 - accuracy: 0.9314 - val_loss: 1.5335 - val_accuracy: 0.5000 - lr: 0.0010
# Epoch 91/100
# 13/13 [==============================] - ETA: 0s - loss: 0.3991 - accuracy: 0.8284
# Epoch 91: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 231ms/step - loss: 0.3991 - accuracy: 0.8284 - val_loss: 1.2869 - val_accuracy: 0.5577 - lr: 0.0010
# Epoch 92/100
# 13/13 [==============================] - ETA: 0s - loss: 0.3055 - accuracy: 0.8676
# Epoch 92: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 230ms/step - loss: 0.3055 - accuracy: 0.8676 - val_loss: 1.3411 - val_accuracy: 0.6538 - lr: 0.0010
# Epoch 93/100
# 13/13 [==============================] - ETA: 0s - loss: 0.2327 - accuracy: 0.9020
# Epoch 93: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 229ms/step - loss: 0.2327 - accuracy: 0.9020 - val_loss: 1.3963 - val_accuracy: 0.6154 - lr: 0.0010
# Epoch 94/100
# 13/13 [==============================] - ETA: 0s - loss: 0.1921 - accuracy: 0.9314
# Epoch 94: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 232ms/step - loss: 0.1921 - accuracy: 0.9314 - val_loss: 1.5590 - val_accuracy: 0.6346 - lr: 0.0010
# Epoch 95/100
# 13/13 [==============================] - ETA: 0s - loss: 0.1795 - accuracy: 0.9265
# Epoch 95: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 235ms/step - loss: 0.1795 - accuracy: 0.9265 - val_loss: 1.5466 - val_accuracy: 0.6346 - lr: 0.0010
# Epoch 96/100
# 13/13 [==============================] - ETA: 0s - loss: 0.1528 - accuracy: 0.9461
# Epoch 96: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 240ms/step - loss: 0.1528 - accuracy: 0.9461 - val_loss: 1.5923 - val_accuracy: 0.6154 - lr: 0.0010
# Epoch 97/100
# 13/13 [==============================] - ETA: 0s - loss: 0.1352 - accuracy: 0.9510
# Epoch 97: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 231ms/step - loss: 0.1352 - accuracy: 0.9510 - val_loss: 1.5992 - val_accuracy: 0.6154 - lr: 0.0010
# Epoch 98/100
# 13/13 [==============================] - ETA: 0s - loss: 0.1390 - accuracy: 0.9461
# Epoch 98: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 232ms/step - loss: 0.1390 - accuracy: 0.9461 - val_loss: 1.7361 - val_accuracy: 0.6538 - lr: 0.0010
# Epoch 99/100
# 13/13 [==============================] - ETA: 0s - loss: 0.1310 - accuracy: 0.9559
# Epoch 99: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 232ms/step - loss: 0.1310 - accuracy: 0.9559 - val_loss: 1.6815 - val_accuracy: 0.5962 - lr: 0.0010
# Epoch 100/100
# 13/13 [==============================] - ETA: 0s - loss: 0.1415 - accuracy: 0.9461
# Epoch 100: val_loss did not improve from 0.67546
# 13/13 [==============================] - 3s 233ms/step - loss: 0.1415 - accuracy: 0.9461 - val_loss: 1.6153 - val_accuracy: 0.6154 - lr: 0.0010

# %%
model = keras.models.load_model('GRU_model_6.h5')

# %%
# Evaluar el modelo en el conjunto de prueba
test_loss, test_accuracy = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {test_accuracy:.2f}")
# Out:
# 3/3 [==============================] - 1s 127ms/step - loss: 0.7350 - accuracy: 0.4722
# Test Accuracy: 0.47

# %%
val_loss, val_accuracy = model.evaluate(x_val, y_val)
print(f"val Accuracy: {val_accuracy:.2f}")
# Out:
# 2/2 [==============================] - 0s 73ms/step - loss: 0.6755 - accuracy: 0.5769
# val Accuracy: 0.58

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import accuracy_score, confusion_matrix, roc_curve, auc, roc_auc_score, precision_recall_curve, average_precision_score

# Convertir el historial de entrenamiento en un DataFrame para facilitar el análisis
log = pd.DataFrame(history.history)

# Realizar las predicciones en el conjunto de prueba
y_pred = model.predict(x_test)
y_pred_classes = (y_pred > 0.5).astype(int).flatten()  # Convertir las probabilidades en etiquetas de clase (0 o 1)

# Calcular el accuracy en el conjunto de prueba
accuracy = accuracy_score(y_test, y_pred_classes)
print(f"Test Accuracy: {accuracy:.2f}")

# Realizar las predicciones en el conjunto de validación
y_val_pred = model.predict(x_val)
y_val_pred_classes = (y_val_pred > 0.5).astype(int).flatten()  # Convertir las probabilidades en etiquetas de clase

# Calcular el accuracy en el conjunto de validación
val_accuracy = accuracy_score(y_val, y_val_pred_classes)
print(f"Validation Accuracy: {val_accuracy:.2f}")

# Calcular y graficar la matriz de confusión para el conjunto de prueba
conf_matrix = confusion_matrix(y_test, y_pred_classes)
conf_matrix_normalized = confusion_matrix(y_test, y_pred_classes, normalize='true')
labels = np.asarray([f'{int(conf_matrix[i, j])}\n({conf_matrix_normalized[i, j]:.2%})' 
                     for i in range(conf_matrix.shape[0]) 
                     for j in range(conf_matrix.shape[1])]).reshape(conf_matrix.shape)

class_names = ['Control', 'Glaucoma']

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_normalized, annot=labels, fmt='', cmap='Blues', cbar=False,
            xticklabels=class_names, yticklabels=class_names)
plt.title('Test set Confusion Matrix')
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()

# Calcular y graficar la matriz de confusión para el conjunto de validación
conf_matrix = confusion_matrix(y_val, y_val_pred_classes)
conf_matrix_normalized = confusion_matrix(y_val, y_val_pred_classes, normalize='true')
labels = np.asarray([f'{int(conf_matrix[i, j])}\n({conf_matrix_normalized[i, j]:.2%})' 
                     for i in range(conf_matrix.shape[0]) 
                     for j in range(conf_matrix.shape[1])]).reshape(conf_matrix.shape)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix_normalized, annot=labels, fmt='', cmap='Blues', cbar=False,
            xticklabels=class_names, yticklabels=class_names)
plt.title('Validation set Confusion Matrix')
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()

# Calcular la curva ROC y el AUC para el conjunto de prueba
y_prob = y_pred.flatten()  # Asegúrate de que sea la probabilidad de la clase positiva
fpr, tpr, thresholds = roc_curve(y_test, y_prob)
auc_value = roc_auc_score(y_test, y_prob)

plt.figure(figsize=(8, 6))
plt.plot(fpr, tpr, color='blue', label=f'ROC curve (AUC = {auc_value:.2f})')
plt.plot([0, 1], [0, 1], color='gray', linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curve')
plt.legend(loc="lower right")
plt.grid(True)
plt.show()

print(f"AUC: {auc_value:.2f}")

# Calcular la curva Precision-Recall y el AUC-PR
precision, recall, thresholds = precision_recall_curve(y_test, y_prob)
auc_pr = average_precision_score(y_test, y_prob)

plt.figure(figsize=(8, 6))
plt.plot(recall, precision, color='blue', label=f'Precision-Recall curve (AUC-PR = {auc_pr:.2f})')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.title('Precision-Recall Curve')
plt.legend(loc="lower left")
plt.grid(True)
plt.show()

# Graficar las pérdidas a lo largo de las épocas
plt.figure(figsize=(10, 5))
plt.plot(log['loss'], label='Training Loss')
plt.plot(log['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Training and Validation Loss Over Epochs')
plt.legend()
plt.show()

# Calcular y graficar el error a lo largo de las épocas
train_error = 1 - log['accuracy']
val_error = 1 - log['val_accuracy']

plt.figure(figsize=(10, 5))
plt.plot(train_error, label='Training Error')
plt.plot(val_error, label='Validation Error')
plt.xlabel('Epochs')
plt.ylabel('Error')
plt.title('Training and Validation Error Over Epochs')
plt.legend()
plt.show()
# Out:
# 3/3 [==============================] - 1s 96ms/step
# Test Accuracy: 0.47
# 2/2 [==============================] - 0s 76ms/step
# Validation Accuracy: 0.58
# AUC: 0.45
